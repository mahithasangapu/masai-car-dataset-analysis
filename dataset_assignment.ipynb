# %% [markdown]
# Task 1 - Data Quality Issues
#
# 1. missing values in columns(null values present)
# 2. Incorrect data types(eg, mileage as object/string)
# 3. duplicate rows in dataset
# 4. inconsistent text formating in brand
# 5.impossible or outlier values (eg:negative price or mileage)

# %% [markdown]
# Task 2 - Data cleaning steps
#
# 1.Drop rows where target(selling_price) is missing
# 2.fill missing values in input features(mean/median/mode)
#
# 3.clean brand column -> strip spaces + convert to lowercase
#
# 4.Extract numeric values from mileage column
#
# 5.remove duplicate rows

# %% [markdown]
# Task 3 - Baseline MAE
#
# Predict: mean of selling_price for all records
#
# Formula:
#  ypred = mean(selling price)
#
#  Baseline model = predict mean selling_price → compute MAE on full cleaned dataset
